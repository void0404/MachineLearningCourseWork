# %%
import joblib
from xgboost import XGBClassifier
import lightgbm

# %%
clf = joblib.load("model5.pkl")
lightgbm.plot_importance(clf,max_num_features=10)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>
